# %% [markdown]
# # import covid data and get florida covid data

# %%
import numpy as np
import pandas as pd

# %%
covid=pd.read_csv('/Users/yoga/Documents/Projects/1_covid19_cre/72_update regression analysis 20220122/1_us-counties_covid20220122.csv')

covid_fl=covid.loc[covid['state']=='Florida']
covid_fl
# Out:
#                date        county    state     fips   cases  deaths
# 411      2020-03-01  Hillsborough  Florida  12057.0       1     0.0
# 412      2020-03-01       Manatee  Florida  12081.0       1     0.0
# 440      2020-03-02  Hillsborough  Florida  12057.0       1     0.0
# 441      2020-03-02       Manatee  Florida  12081.0       1     0.0
# 474      2020-03-03  Hillsborough  Florida  12057.0       2     0.0
# ...             ...           ...      ...      ...     ...     ...
# 2138790  2022-01-22       Unknown  Florida      NaN   22916   605.0
# 2138791  2022-01-22       Volusia  Florida  12127.0  102609  1659.0
# 2138792  2022-01-22       Wakulla  Florida  12129.0    8520   108.0
# 2138793  2022-01-22        Walton  Florida  12131.0   14760   177.0
# 2138794  2022-01-22    Washington  Florida  12133.0    5810    87.0
#
# [45814 rows x 6 columns]

# %%
time=['2020-03-31','2020-06-30','2020-09-30','2020-12-31','2021-03-31','2021-06-30','2021-09-30','2021-12-31']

covid_fl_qtr=covid_fl.loc[covid_fl['date'].isin(time)]

covid_fl_qtr
# Out:
#                date      county    state     fips  cases  deaths
# 21976    2020-03-31     Alachua  Florida  12001.0     87     0.0
# 21977    2020-03-31       Baker  Florida  12003.0      9     0.0
# 21978    2020-03-31         Bay  Florida  12005.0      8     0.0
# 21979    2020-03-31    Bradford  Florida  12007.0      2     0.0
# 21980    2020-03-31     Brevard  Florida  12009.0     37     0.0
# ...             ...         ...      ...      ...    ...     ...
# 2067246  2021-12-31     Unknown  Florida      NaN      5   162.0
# 2067247  2021-12-31     Volusia  Florida  12127.0  82954  1647.0
# 2067248  2021-12-31     Wakulla  Florida  12129.0   6803   106.0
# 2067249  2021-12-31      Walton  Florida  12131.0  12464   173.0
# 2067250  2021-12-31  Washington  Florida  12133.0   4707    75.0
#
# [531 rows x 6 columns]

# %%
covid_fl_qtr['quarter']=''
covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2020-03-31']='2020 Q1'
covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2020-06-30']='2020 Q2'
covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2020-09-30']='2020 Q3'
covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2020-12-31']='2020 Q4'

covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2021-03-31']='2021 Q1'
covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2021-06-30']='2021 Q2'
covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2021-09-30']='2021 Q3'
covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2021-12-31']='2021 Q4'
# Out:
# <ipython-input-20-6bf9af656386>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_fl_qtr['quarter']=''
# <ipython-input-20-6bf9af656386>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2020-03-31']='2020 Q1'
# /Users/yoga/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-20-6bf9af656386>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2020-06-30']='2020 Q2'
# <ipython-input-20-6bf9af656386>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2020-09-30']='2020 Q3'
# <ipython-input-20-6bf9af656386>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2020-12-31']='2020 Q4'
# <ipython-input-20-6bf9af656386>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2021-03-31']='2021 Q1'
# <ipython-input-20-6bf9af656386>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2021-06-30']='2021 Q2'
# <ipython-input-20-6bf9af656386>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2021-09-30']='2021 Q3'
# <ipython-input-20-6bf9af656386>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_fl_qtr['quarter'][covid_fl_qtr['date']=='2021-12-31']='2021 Q4'

# %%
covid_fl_qtr
# Out:
#                date      county    state     fips  cases  deaths  quarter
# 21976    2020-03-31     Alachua  Florida  12001.0     87     0.0  2020 Q1
# 21977    2020-03-31       Baker  Florida  12003.0      9     0.0  2020 Q1
# 21978    2020-03-31         Bay  Florida  12005.0      8     0.0  2020 Q1
# 21979    2020-03-31    Bradford  Florida  12007.0      2     0.0  2020 Q1
# 21980    2020-03-31     Brevard  Florida  12009.0     37     0.0  2020 Q1
# ...             ...         ...      ...      ...    ...     ...      ...
# 2067246  2021-12-31     Unknown  Florida      NaN      5   162.0  2021 Q4
# 2067247  2021-12-31     Volusia  Florida  12127.0  82954  1647.0  2021 Q4
# 2067248  2021-12-31     Wakulla  Florida  12129.0   6803   106.0  2021 Q4
# 2067249  2021-12-31      Walton  Florida  12131.0  12464   173.0  2021 Q4
# 2067250  2021-12-31  Washington  Florida  12133.0   4707    75.0  2021 Q4
#
# [531 rows x 7 columns]

# %%
#这里缺少三个MSA,如下：33124  Miami - FL48424  Palm Beach - FL；22744 Fort Lauderdale - FL

cbsa2coun=pd.read_excel('/Users/yoga/Dropbox/1 新冠和商业地产/101 CRE second time 202205/4-5 cbsa 2 county name.xlsx')
cbsa2coun
# Out:
#     CBSAFP                               CBSA NAME   County NAME
# 0    23540                         Gainesville, FL          Levy
# 1    23540                         Gainesville, FL       Alachua
# 2    23540                         Gainesville, FL     Gilchrist
# 3    18880  Crestview-Fort Walton Beach-Destin, FL        Walton
# 4    18880  Crestview-Fort Walton Beach-Destin, FL      Okaloosa
# 5    19660  Deltona-Daytona Beach-Ormond Beach, FL       Flagler
# 6    19660  Deltona-Daytona Beach-Ormond Beach, FL       Volusia
# 7    15980               Cape Coral-Fort Myers, FL           Lee
# 8    26140                   Homosassa Springs, FL        Citrus
# 9    27260                        Jacksonville, FL          Clay
# 10   27260                        Jacksonville, FL        Nassau
# 11   27260                        Jacksonville, FL     St. Johns
# 12   27260                        Jacksonville, FL         Baker
# 13   27260                        Jacksonville, FL         Duval
# 14   29460               Lakeland-Winter Haven, FL          Polk
# 15   34940                 Naples-Marco Island, FL       Collier
# 16   35840       North Port-Sarasota-Bradenton, FL       Manatee
# 17   35840       North Port-Sarasota-Bradenton, FL      Sarasota
# 18   36100                               Ocala, FL        Marion
# 19   36740           Orlando-Kissimmee-Sanford, FL       Osceola
# 20   36740           Orlando-Kissimmee-Sanford, FL        Orange
# 21   36740           Orlando-Kissimmee-Sanford, FL          Lake
# 22   36740           Orlando-Kissimmee-Sanford, FL      Seminole
# 23   37340       Palm Bay-Melbourne-Titusville, FL       Brevard
# 24   37460                         Panama City, FL           Bay
# 25   37860          Pensacola-Ferry Pass-Brent, FL      Escambia
# 26   37860          Pensacola-Ferry Pass-Brent, FL    Santa Rosa
# 27   38940                      Port St. Lucie, FL     St. Lucie
# 28   38940                      Port St. Lucie, FL        Martin
# 29   39460                         Punta Gorda, FL     Charlotte
# 30   42680                Sebastian-Vero Beach, FL  Indian River
# 31   42700                   Sebring-Avon Park, FL     Highlands
# 32   45220                         Tallahassee, FL       Gadsden
# 33   45220                         Tallahassee, FL       Wakulla
# 34   45220                         Tallahassee, FL     Jefferson
# 35   45220                         Tallahassee, FL          Leon
# 36   45300     Tampa-St. Petersburg-Clearwater, FL      Hernando
# 37   45300     Tampa-St. Petersburg-Clearwater, FL      Pinellas
# 38   45300     Tampa-St. Petersburg-Clearwater, FL         Pasco
# 39   45300     Tampa-St. Petersburg-Clearwater, FL  Hillsborough
# 40   45540                        The Villages, FL        Sumter
# 41   22744                     Fort Lauderdale, FL       Broward
# 42   33124                               Miami, FL    Miami-Dade
# 43   48424                          Palm Beach, FL    Palm Beach

# %%
len(cbsa2coun['CBSA NAME'].unique())
# Out:
# 24

# %%
#try to merge
covid2_merge=pd.merge(left=covid_fl_qtr,right=cbsa2coun,left_on='county',right_on='County NAME',how='left')

# %%
covid2_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 531 entries, 0 to 530
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         531 non-null    object
#  1   county       531 non-null    object
#  2   state        531 non-null    object
#  3   fips         524 non-null    float64
#  4   cases        531 non-null    int64
#  5   deaths       531 non-null    float64
#  6   quarter      531 non-null    object
#  7   CBSAFP       350 non-null    float64
#  8   CBSA NAME    350 non-null    object
#  9   County NAME  350 non-null    object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 45.6+ KB

# %%
len(covid2_merge['CBSAFP'].unique()) #多了一个nan
# Out:
# 25

# %%
len(cbsa2coun['County NAME'].unique())
# Out:
# 44

# %%
covid2_merge2=covid2_merge.copy()
covid2_merge2=covid2_merge2.dropna()

# %%
len(covid2_merge2['County NAME'].unique())
# Out:
# 44

# %%
covid2_merge2
# Out:
#            date     county    state     fips  cases  deaths  quarter   CBSAFP  \
# 0    2020-03-31    Alachua  Florida  12001.0     87     0.0  2020 Q1  23540.0
# 1    2020-03-31      Baker  Florida  12003.0      9     0.0  2020 Q1  27260.0
# 2    2020-03-31        Bay  Florida  12005.0      8     0.0  2020 Q1  37460.0
# 4    2020-03-31    Brevard  Florida  12009.0     37     0.0  2020 Q1  37340.0
# 5    2020-03-31    Broward  Florida  12011.0   1219    12.0  2020 Q1  22744.0
# ..          ...        ...      ...      ...    ...     ...      ...      ...
# 521  2021-12-31  St. Lucie  Florida  12111.0  52135  1047.0  2021 Q4  38940.0
# 522  2021-12-31     Sumter  Florida  12119.0  15405   475.0  2021 Q4  45540.0
# 527  2021-12-31    Volusia  Florida  12127.0  82954  1647.0  2021 Q4  19660.0
# 528  2021-12-31    Wakulla  Florida  12129.0   6803   106.0  2021 Q4  45220.0
# 529  2021-12-31     Walton  Florida  12131.0  12464   173.0  2021 Q4  18880.0
#
#                                   CBSA NAME County NAME
# 0                           Gainesville, FL     Alachua
# 1                          Jacksonville, FL       Baker
# 2                           Panama City, FL         Bay
# 4         Palm Bay-Melbourne-Titusville, FL     Brevard
# 5                       Fort Lauderdale, FL     Broward
# ..                                      ...         ...
# 521                      Port St. Lucie, FL   St. Lucie
# 522                        The Villages, FL      Sumter
# 527  Deltona-Daytona Beach-Ormond Beach, FL     Volusia
# 528                         Tallahassee, FL     Wakulla
# 529  Crestview-Fort Walton Beach-Destin, FL      Walton
#
# [350 rows x 10 columns]

# %%
covid2_merge2['quarter_CBSAFP']=covid2_merge2['quarter'].astype(str)+"&"+covid2_merge2['CBSAFP'].astype(int).astype(str)
covid2_merge2['quarter_CBSAFP']
# Out:
# 0      2020 Q1&23540
# 1      2020 Q1&27260
# 2      2020 Q1&37460
# 4      2020 Q1&37340
# 5      2020 Q1&22744
#            ...
# 521    2021 Q4&38940
# 522    2021 Q4&45540
# 527    2021 Q4&19660
# 528    2021 Q4&45220
# 529    2021 Q4&18880
# Name: quarter_CBSAFP, Length: 350, dtype: object

# %%
covid2_merge2[covid2_merge2['quarter_CBSAFP']=='2021 Q4&38940']
# Out:
#            date     county    state     fips  cases  deaths  quarter   CBSAFP  \
# 504  2021-12-31     Martin  Florida  12085.0  22335   523.0  2021 Q4  38940.0
# 521  2021-12-31  St. Lucie  Florida  12111.0  52135  1047.0  2021 Q4  38940.0
#
#               CBSA NAME County NAME quarter_CBSAFP
# 504  Port St. Lucie, FL      Martin  2021 Q4&38940
# 521  Port St. Lucie, FL   St. Lucie  2021 Q4&38940

# %%
covid2_merge2.loc[i]['county']
# Out:
# 'Alachua'

# %%
#create a dict to calcualte the cases and death.
quarter_CBSAFP2case={}
quarter_CBSAFP2death={}

for i in covid2_merge2.index:
    covid2_merge2i=covid2_merge2.loc[i]['quarter_CBSAFP']
    
    if covid2_merge2i in quarter_CBSAFP2case.keys():
        quarter_CBSAFP2case[covid2_merge2i]=quarter_CBSAFP2case[covid2_merge2i]+covid2_merge2.loc[i]['cases']
        quarter_CBSAFP2death[covid2_merge2i]=quarter_CBSAFP2death[covid2_merge2i]+covid2_merge2.loc[i]['deaths']   
    else:      
        quarter_CBSAFP2case[covid2_merge2i]=covid2_merge2.loc[i]['cases']
        quarter_CBSAFP2death[covid2_merge2i]=covid2_merge2.loc[i]['deaths']

# %%
quarter_CBSAFP2case['2021 Q4&38940']
# Out:
# 74470

# %%
22335+52135
# Out:
# 74470

# %%
pd_quarter_CBSAFP2case=pd.DataFrame(quarter_CBSAFP2case.items())
pd_quarter_CBSAFP2death=pd.DataFrame(quarter_CBSAFP2death.items())

pd_quarter_CBSAFP2death = pd_quarter_CBSAFP2death.rename({0:'quarter_cbsa', 1:'aggregate_death'}, axis='columns')
pd_quarter_CBSAFP2death

pd_quarter_CBSAFP2case = pd_quarter_CBSAFP2case.rename({0:'quarter_cbsa', 1:'aggregate_case'}, axis='columns')
pd_quarter_CBSAFP2case

pd_quarter_CBSAFP2case_death=pd_quarter_CBSAFP2case.merge(pd_quarter_CBSAFP2death,left_on='quarter_cbsa',right_on='quarter_cbsa',how='left')

#pd_quarter_CBSAFP2case_death.to_csv('20_aggregate_death_case_covid_2020_2021.csv',index=0)

# %%
pd_quarter_CBSAFP2case_death
# Out:
#       quarter_cbsa  aggregate_case  aggregate_death
# 0    2020 Q1&23540              89              0.0
# 1    2020 Q1&27260             346             11.0
# 2    2020 Q1&37460               8              0.0
# 3    2020 Q1&37340              37              0.0
# 4    2020 Q1&22744            1219             12.0
# ..             ...             ...              ...
# 187  2021 Q4&33124          847746           9260.0
# 188  2021 Q4&18880           48621            754.0
# 189  2021 Q4&48424          268242           4322.0
# 190  2021 Q4&29460          140400           2531.0
# 191  2021 Q4&45540           15405            475.0
#
# [192 rows x 3 columns]

# %% [markdown]
# ## change aggregated number to number in current quarter

# %%
cbsa2deaths_current=dict()
cbsa2cases_current=dict()

quarter=['2020 Q1','2020 Q2','2020 Q3','2020 Q4','2021 Q1','2021 Q2','2021 Q3','2021 Q4']

for i in pd_quarter_CBSAFP2case_death.index:
    cbsa=pd_quarter_CBSAFP2case_death['quarter_cbsa'][i]
    cbsa_period=cbsa.split('&')[0]
    cbsa_code=cbsa.split('&')[1]
    if cbsa_period=='2020 Q1':
        cbsa2deaths_current[cbsa]=pd_quarter_CBSAFP2case_death['aggregate_death'][i]
        cbsa2cases_current[cbsa]=pd_quarter_CBSAFP2case_death['aggregate_case'][i]
    else:
        if cbsa_period not in quarter:
            print('Could not find ', cbsa_period)
            break
        cur_indx = quarter.index(cbsa_period)
        pre_cbsa_period = quarter[cur_indx-1]
        pre_cbsa_code=cbsa_code
        pre_cbsa=pre_cbsa_period+'&'+str(pre_cbsa_code)
        pre_case=pd_quarter_CBSAFP2case_death[pd_quarter_CBSAFP2case_death['quarter_cbsa']==pre_cbsa]['aggregate_case'].values[0]
        pre_death=pd_quarter_CBSAFP2case_death[pd_quarter_CBSAFP2case_death['quarter_cbsa']==pre_cbsa]['aggregate_death'].values[0]
       
        cbsa2deaths_current[cbsa]=pd_quarter_CBSAFP2case_death['aggregate_death'][i]-pre_death
        cbsa2cases_current[cbsa]=pd_quarter_CBSAFP2case_death['aggregate_case'][i]-pre_case
        
        
        
        
        #print(pre_cbsa_period, '->', cbsa_period)

# %%
pd_quarter_CBSAFP2case_current=pd.DataFrame(cbsa2cases_current.items())
pd_quarter_CBSAFP2death_current=pd.DataFrame(cbsa2deaths_current.items())

pd_quarter_CBSAFP2death_current = pd_quarter_CBSAFP2death_current.rename({0:'quarter_cbsa', 1:'current_death'}, axis='columns')
pd_quarter_CBSAFP2death

pd_quarter_CBSAFP2case_current = pd_quarter_CBSAFP2case_current.rename({0:'quarter_cbsa', 1:'current_case'}, axis='columns')
pd_quarter_CBSAFP2case

pd_quarter_CBSAFP2case_death_current=pd_quarter_CBSAFP2case_current.merge(pd_quarter_CBSAFP2death_current,left_on='quarter_cbsa',right_on='quarter_cbsa',how='left')

# %%
#pd_quarter_CBSAFP2case_death_current.to_csv('21_current_death_case_covid_2020_2021.csv',index=0)


#pd_quarter_CBSAFP2case_death.to_csv('20_aggregate_death_case_covid_2020_2021.csv',index=0)

# %%
pd_quarter_CBSAFP2case_death
# Out:
#       quarter_cbsa  aggregate_case  aggregate_death
# 0    2020 Q1&23540              89              0.0
# 1    2020 Q1&27260             346             11.0
# 2    2020 Q1&37460               8              0.0
# 3    2020 Q1&37340              37              0.0
# 4    2020 Q1&22744            1219             12.0
# ..             ...             ...              ...
# 187  2021 Q4&33124          847746           9260.0
# 188  2021 Q4&18880           48621            754.0
# 189  2021 Q4&48424          268242           4322.0
# 190  2021 Q4&29460          140400           2531.0
# 191  2021 Q4&45540           15405            475.0
#
# [192 rows x 3 columns]

# %%
pd_quarter_CBSAFP2case_death[pd_quarter_CBSAFP2case_death['quarter_cbsa']=='2021 Q3&45540']
# Out:
#       quarter_cbsa  aggregate_case  aggregate_death
# 167  2021 Q3&45540           13990            428.0

# %% [markdown]
# #  import costar data and combine with costar data

# %%
retail=pd.read_excel('/Users/yoga/Documents/Projects/1_covid19_cre/72_update regression analysis 20220122/Retail_01-18-2022.xlsx')
office=pd.read_excel('/Users/yoga/Documents/Projects/1_covid19_cre/72_update regression analysis 20220122/Office_01-18-2022.xlsx')
industry=pd.read_excel('/Users/yoga/Documents/Projects/1_covid19_cre/72_update regression analysis 20220122/Industrial_01-18-2022.xlsx')

# %%
#df[df['ids'].str.contains("ball")]
retail2=retail[(retail['Period'].str.contains('2018 Q'))|(retail['Period'].str.contains('2019 Q'))|(retail['Period'].str.contains('2020 Q'))|(retail['Period'].str.contains('2021 Q'))]

office2=office[(office['Period'].str.contains('2018 Q'))|(office['Period'].str.contains('2019 Q'))|(office['Period'].str.contains('2020 Q'))|(office['Period'].str.contains('2021 Q'))]

industry2=industry[(industry['Period'].str.contains('2018 Q'))|(industry['Period'].str.contains('2019 Q'))|(industry['Period'].str.contains('2020 Q'))|(industry['Period'].str.contains('2021 Q'))]

# %%
industry2
# Out:
#      Property Class Name   Period Slice    As Of      Geography Name  \
# 144           Industrial  2018 Q1   All  2022 Q1  Daytona Beach - FL
# 145           Industrial  2018 Q2   All  2022 Q1  Daytona Beach - FL
# 146           Industrial  2018 Q3   All  2022 Q1  Daytona Beach - FL
# 147           Industrial  2018 Q4   All  2022 Q1  Daytona Beach - FL
# 148           Industrial  2019 Q1   All  2022 Q1  Daytona Beach - FL
# ...                  ...      ...   ...      ...                 ...
# 3858          Industrial  2020 Q4   All  2022 Q1   The Villages - FL
# 3859          Industrial  2021 Q1   All  2022 Q1   The Villages - FL
# 3860          Industrial  2021 Q2   All  2022 Q1   The Villages - FL
# 3861          Industrial  2021 Q3   All  2022 Q1   The Villages - FL
# 3862          Industrial  2021 Q4   All  2022 Q1   The Villages - FL
#
#       CBSA Code Property Type Forecast Scenario Geography Type Geography Code  \
# 144       19660    Industrial         Base Case          Metro         G41649
# 145       19660    Industrial         Base Case          Metro         G41649
# 146       19660    Industrial         Base Case          Metro         G41649
# 147       19660    Industrial         Base Case          Metro         G41649
# 148       19660    Industrial         Base Case          Metro         G41649
# ...         ...           ...               ...            ...            ...
# 3858      45540    Industrial         Base Case          Metro         G39580
# 3859      45540    Industrial         Base Case          Metro         G39580
# 3860      45540    Industrial         Base Case          Metro         G39580
# 3861      45540    Industrial         Base Case          Metro         G39580
# 3862      45540    Industrial         Base Case          Metro         G39580
#
#       ...  Sold Building SF  Total Employment  Total Return  \
# 144   ...          227031.0     202634.593750      0.121489
# 145   ...          623631.0     203406.906250      0.123515
# 146   ...          171463.0     204901.390625      0.124135
# 147   ...          192826.0     205294.500000      0.125630
# 148   ...           76136.0     205313.906250      0.125999
# ...   ...               ...               ...           ...
# 3858  ...               NaN      31842.000000      0.138026
# 3859  ...           13920.0      31496.189453      0.136862
# 3860  ...           72792.0      31540.269531      0.142301
# 3861  ...           23266.0      31965.048828      0.156650
# 3862  ...            2896.0      32531.201172      0.168221
#
#       Total Sales Volume  Transaction Sale Price/SF  \
# 144           16597775.0                      82.98
# 145           41943208.0                      71.42
# 146            5165600.0                      44.95
# 147            5367000.0                      46.90
# 148            1646000.0                      72.46
# ...                  ...                        ...
# 3858                 0.0                        NaN
# 3859           1400000.0                     100.57
# 3860           5357195.0                      73.60
# 3861           3750000.0                     161.18
# 3862            300000.0                     103.59
#
#       Under Construction Buildings  Under Construction SF  Vacancy Rate  \
# 144                            4.0                54000.0      0.029080
# 145                            3.0                36000.0      0.032372
# 146                            4.0                37160.0      0.031292
# 147                            5.0                93120.0      0.043182
# 148                            3.0               124960.0      0.046645
# ...                            ...                    ...           ...
# 3858                           7.0                81600.0      0.021936
# 3859                           7.0                81600.0      0.013023
# 3860                           7.0                81600.0      0.048391
# 3861                           2.0                21600.0      0.054643
# 3862                           2.0                21600.0      0.050971
#
#       Vacant Available %  Vacant Available SF
# 144             0.026570             636770.0
# 145             0.028699             688304.0
# 146             0.030832             739480.0
# 147             0.043182            1035788.0
# 148             0.043040            1033872.0
# ...                  ...                  ...
# 3858            0.021936              34530.0
# 3859            0.013023              20500.0
# 3860            0.048391              76172.0
# 3861            0.054643              89292.0
# 3862            0.050971              83292.0
#
# [384 rows x 66 columns]

# %%
#generate the key word for merge.

retail2['quarter_CBSAFP']=retail2['Period'].astype(str)+"&"+retail2['CBSA Code'].astype(str)

office2['quarter_CBSAFP']=office2['Period'].astype(str)+"&"+office2['CBSA Code'].astype(str)

industry2['quarter_CBSAFP']=industry2['Period'].astype(str)+"&"+industry2['CBSA Code'].astype(str)
# Out:
# <ipython-input-56-c4f0b6e586eb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   retail2['quarter_CBSAFP']=retail2['Period'].astype(str)+"&"+retail2['CBSA Code'].astype(str)
# <ipython-input-56-c4f0b6e586eb>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   office2['quarter_CBSAFP']=office2['Period'].astype(str)+"&"+office2['CBSA Code'].astype(str)
# <ipython-input-56-c4f0b6e586eb>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   industry2['quarter_CBSAFP']=industry2['Period'].astype(str)+"&"+industry2['CBSA Code'].astype(str)

# %%
industry2
# Out:
#      Property Class Name   Period Slice    As Of      Geography Name  \
# 144           Industrial  2018 Q1   All  2022 Q1  Daytona Beach - FL
# 145           Industrial  2018 Q2   All  2022 Q1  Daytona Beach - FL
# 146           Industrial  2018 Q3   All  2022 Q1  Daytona Beach - FL
# 147           Industrial  2018 Q4   All  2022 Q1  Daytona Beach - FL
# 148           Industrial  2019 Q1   All  2022 Q1  Daytona Beach - FL
# ...                  ...      ...   ...      ...                 ...
# 3858          Industrial  2020 Q4   All  2022 Q1   The Villages - FL
# 3859          Industrial  2021 Q1   All  2022 Q1   The Villages - FL
# 3860          Industrial  2021 Q2   All  2022 Q1   The Villages - FL
# 3861          Industrial  2021 Q3   All  2022 Q1   The Villages - FL
# 3862          Industrial  2021 Q4   All  2022 Q1   The Villages - FL
#
#       CBSA Code Property Type Forecast Scenario Geography Type Geography Code  \
# 144       19660    Industrial         Base Case          Metro         G41649
# 145       19660    Industrial         Base Case          Metro         G41649
# 146       19660    Industrial         Base Case          Metro         G41649
# 147       19660    Industrial         Base Case          Metro         G41649
# 148       19660    Industrial         Base Case          Metro         G41649
# ...         ...           ...               ...            ...            ...
# 3858      45540    Industrial         Base Case          Metro         G39580
# 3859      45540    Industrial         Base Case          Metro         G39580
# 3860      45540    Industrial         Base Case          Metro         G39580
# 3861      45540    Industrial         Base Case          Metro         G39580
# 3862      45540    Industrial         Base Case          Metro         G39580
#
#       ...  Total Employment  Total Return  Total Sales Volume  \
# 144   ...     202634.593750      0.121489          16597775.0
# 145   ...     203406.906250      0.123515          41943208.0
# 146   ...     204901.390625      0.124135           5165600.0
# 147   ...     205294.500000      0.125630           5367000.0
# 148   ...     205313.906250      0.125999           1646000.0
# ...   ...               ...           ...                 ...
# 3858  ...      31842.000000      0.138026                 0.0
# 3859  ...      31496.189453      0.136862           1400000.0
# 3860  ...      31540.269531      0.142301           5357195.0
# 3861  ...      31965.048828      0.156650           3750000.0
# 3862  ...      32531.201172      0.168221            300000.0
#
#       Transaction Sale Price/SF  Under Construction Buildings  \
# 144                       82.98                           4.0
# 145                       71.42                           3.0
# 146                       44.95                           4.0
# 147                       46.90                           5.0
# 148                       72.46                           3.0
# ...                         ...                           ...
# 3858                        NaN                           7.0
# 3859                     100.57                           7.0
# 3860                      73.60                           7.0
# 3861                     161.18                           2.0
# 3862                     103.59                           2.0
#
#       Under Construction SF  Vacancy Rate  Vacant Available %  \
# 144                 54000.0      0.029080            0.026570
# 145                 36000.0      0.032372            0.028699
# 146                 37160.0      0.031292            0.030832
# 147                 93120.0      0.043182            0.043182
# 148                124960.0      0.046645            0.043040
# ...                     ...           ...                 ...
# 3858                81600.0      0.021936            0.021936
# 3859                81600.0      0.013023            0.013023
# 3860                81600.0      0.048391            0.048391
# 3861                21600.0      0.054643            0.054643
# 3862                21600.0      0.050971            0.050971
#
#       Vacant Available SF  quarter_CBSAFP
# 144              636770.0   2018 Q1&19660
# 145              688304.0   2018 Q2&19660
# 146              739480.0   2018 Q3&19660
# 147             1035788.0   2018 Q4&19660
# 148             1033872.0   2019 Q1&19660
# ...                   ...             ...
# 3858              34530.0   2020 Q4&45540
# 3859              20500.0   2021 Q1&45540
# 3860              76172.0   2021 Q2&45540
# 3861              89292.0   2021 Q3&45540
# 3862              83292.0   2021 Q4&45540
#
# [384 rows x 67 columns]

# %% [markdown]
# # merge case and death to costar.

# %%
industry3=industry2.merge(pd_quarter_CBSAFP2case_death_current,left_on='quarter_CBSAFP',right_on='quarter_cbsa',how='left')

retail3=retail2.merge(pd_quarter_CBSAFP2case_death_current,left_on='quarter_CBSAFP',right_on='quarter_cbsa',how='left')

office3=office2.merge(pd_quarter_CBSAFP2case_death_current,left_on='quarter_CBSAFP',right_on='quarter_cbsa',how='left')

# %%
office3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 384 entries, 0 to 383
# Data columns (total 70 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Property Class Name           384 non-null    object
#  1   Period                        384 non-null    object
#  2   Slice                         384 non-null    object
#  3   As Of                         384 non-null    object
#  4   Geography Name                384 non-null    object
#  5   CBSA Code                     384 non-null    int64
#  6   Property Type                 384 non-null    object
#  7   Forecast Scenario             384 non-null    object
#  8   Geography Type                384 non-null    object
#  9   Geography Code                384 non-null    object
#  10  Appreciation Return           384 non-null    float64
#  11  Asset Value                   384 non-null    float64
#  12  Availability Rate             384 non-null    float64
#  13  Available SF                  384 non-null    float64
#  14  Average Sale Price            381 non-null    float64
#  15  Cap Rate                      262 non-null    float64
#  16  Cap Rate Transactions         382 non-null    float64
#  17  Capital Value Index           384 non-null    float64
#  18  Demand SF                     384 non-null    float64
#  19  Demolished SF                 384 non-null    float64
#  20  Existing Buildings            384 non-null    float64
#  21  Gross Delivered Buildings     384 non-null    float64
#  22  Gross Delivered SF            384 non-null    float64
#  23  Households                    384 non-null    float64
#  24  Income Return                 384 non-null    float64
#  25  Industrial Employment         384 non-null    float64
#  26  Inventory SF                  384 non-null    int64
#  27  Leasing Activity SF           380 non-null    float64
#  28  Market Cap Rate               384 non-null    float64
#  29  Market Rent Growth            384 non-null    float64
#  30  Market Rent Growth 12 Mo      384 non-null    float64
#  31  Market Rent Index             384 non-null    float64
#  32  Market Rent/SF                384 non-null    float64
#  33  Market Sale Price Growth      384 non-null    float64
#  34  Market Sale Price Index       384 non-null    float64
#  35  Market Sale Price Per SF      384 non-null    float64
#  36  Median Cap Rate               262 non-null    float64
#  37  Median Household Income       384 non-null    float64
#  38  Median Price/Bldg SF          381 non-null    float64
#  39  Net Absorption SF             384 non-null    float64
#  40  Net Absorption SF 12 Mo       384 non-null    float64
#  41  Net Absorption SF Direct      384 non-null    float64
#  42  Net Absorption SF Sublet      262 non-null    float64
#  43  Net Delivered SF              384 non-null    float64
#  44  Net Delivered SF 12 Mo        384 non-null    float64
#  45  NOI Index                     384 non-null    float64
#  46  Occupancy Rate                384 non-null    float64
#  47  Office Base Rent Direct       384 non-null    float64
#  48  Office Base Rent Overall      384 non-null    float64
#  49  Office Base Rent Sublet       309 non-null    float64
#  50  Office Employment             384 non-null    float64
#  51  Office Gross Rent Direct      384 non-null    float64
#  52  Office Gross Rent Overall     384 non-null    float64
#  53  Office Gross Rent Sublet      246 non-null    float64
#  54  Population                    384 non-null    float64
#  55  Sales Volume Transactions     382 non-null    float64
#  56  Sold Building SF              382 non-null    float64
#  57  Total Employment              384 non-null    float64
#  58  Total Return                  384 non-null    float64
#  59  Total Sales Volume            384 non-null    float64
#  60  Transaction Sale Price/SF     381 non-null    float64
#  61  Under Construction Buildings  384 non-null    float64
#  62  Under Construction SF         336 non-null    float64
#  63  Vacancy Rate                  384 non-null    float64
#  64  Vacant Available %            384 non-null    float64
#  65  Vacant Available SF           384 non-null    float64
#  66  quarter_CBSAFP                384 non-null    object
#  67  quarter_cbsa                  192 non-null    object
#  68  current_case                  192 non-null    float64
#  69  current_death                 192 non-null    float64
# dtypes: float64(57), int64(2), object(11)
# memory usage: 213.0+ KB

# %% [markdown]
# ## get the log

# %%
#取对数 industry
industry3['ln_cases_current']=industry3['current_case']
industry3['ln_cases_current'][(industry3.current_case.notnull())&(industry3['ln_cases_current']!=0)]=np.log(industry3['current_case'][(industry3.current_case.notnull())&(industry3['ln_cases_current']!=0)])


industry3['ln_death_current']=industry3['current_death']
industry3['ln_death_current'][(industry3.current_death.notnull())&(industry3['ln_death_current']!=0)]=np.log(industry3['current_death'][(industry3.current_death.notnull())&(industry3['ln_death_current']!=0)])


#取对数 retail
retail3['ln_cases_current']=retail3['current_case']
retail3['ln_cases_current'][(retail3.current_case.notnull())&(retail3['ln_cases_current']!=0)]=np.log(retail3['current_case'][(retail3.current_case.notnull())&(retail3['ln_cases_current']!=0)])


retail3['ln_death_current']=retail3['current_death']
retail3['ln_death_current'][(retail3.current_death.notnull())&(retail3['ln_death_current']!=0)]=np.log(retail3['current_death'][(retail3.current_death.notnull())&(retail3['ln_death_current']!=0)])

#取对数 office
office3['ln_cases_current']=office3['current_case']
office3['ln_cases_current'][(office3.current_case.notnull())&(office3['ln_cases_current']!=0)]=np.log(office3['current_case'][(office3.current_case.notnull())&(office3['ln_cases_current']!=0)])


office3['ln_death_current']=office3['current_death']
office3['ln_death_current'][(office3.current_death.notnull())&(office3['ln_death_current']!=0)]=np.log(office3['current_death'][(office3.current_death.notnull())&(office3['ln_death_current']!=0)])
# Out:
# /Users/yoga/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-111-082dd0d23bd6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   industry3['ln_cases_current'][(industry3.current_case.notnull())&(industry3['ln_cases_current']!=0)]=np.log(industry3['current_case'][(industry3.current_case.notnull())&(industry3['ln_cases_current']!=0)])
# <ipython-input-111-082dd0d23bd6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   industry3['ln_death_current'][(industry3.current_death.notnull())&(industry3['ln_death_current']!=0)]=np.log(industry3['current_death'][(industry3.current_death.notnull())&(industry3['ln_death_current']!=0)])
# /Users/yoga/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-111-082dd0d23bd6>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   retail3['ln_cases_current'][(retail3.current_case.notnull())&(retail3['ln_cases_current']!=0)]=np.log(retail3['current_case'][(retail3.current_case.notnull())&(retail3['ln_cases_current']!=0)])
# <ipython-input-111-082dd0d23bd6>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   retail3['ln_death_current'][(retail3.current_death.notnull())&(retail3['ln_death_current']!=0)]=np.log(retail3['current_death'][(retail3.current_death.notnull())&(retail3['ln_death_current']!=0)])
# /Users/yoga/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-111-082dd0d23bd6>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   office3['ln_cases_current'][(office3.current_case.notnull())&(office3['ln_cases_current']!=0)]=np.log(office3['current_case'][(office3.current_case.notnull())&(office3['ln_cases_current']!=0)])
# <ipython-input-111-082dd0d23bd6>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   office3['ln_death_current'][(office3.current_death.notnull())&(office3['ln_death_current']!=0)]=np.log(office3['current_death'][(office3.current_death.notnull())&(office3['ln_death_current']!=0)])

# %%
office3[['ln_cases_current','ln_death_current']] = office3[['ln_cases_current','ln_death_current']].fillna(0)
retail3[['ln_cases_current','ln_death_current']] = retail3[['ln_cases_current','ln_death_current']].fillna(0)
industry3[['ln_cases_current','ln_death_current']] = industry3[['ln_cases_current','ln_death_current']].fillna(0)


#office3.to_csv('31_office_covid_2018-2021.csv',index=0)

#retail3.to_csv('32_retail_covid_2018-2021.csv',index=0)

#industry3.to_csv('33_industry_covid_2018-2021.csv',index=0)

# %% [markdown]
# ## fixed effect regression

# %% [markdown]
# ##目标处理数据，然后用stata进行fixed effect

# %%
office3=pd.read_csv('/Users/yoga/Dropbox/1 新冠和商业地产/101 CRE second time 202205/31_office_covid_2018-2021.csv')
retail3=pd.read_csv('/Users/yoga/Dropbox/1 新冠和商业地产/101 CRE second time 202205/32_retail_covid_2018-2021.csv')
industry3=pd.read_csv('/Users/yoga/Dropbox/1 新冠和商业地产/101 CRE second time 202205/33_industry_covid_2018-2021.csv')

# %%
period=office3['Period'].unique().tolist()
period

# %%
t=list(range(1,17))
period2t=zip(period, t)
period2t
dict_period2t = dict(period2t)
dict_period2t
new_data = {'Period':list(dict_period2t.keys()), 'TimeIndex': list(dict_period2t.values())}

df = pd.DataFrame.from_dict(new_data)
df
# Out:
#      Period  TimeIndex
# 0   2018 Q1          1
# 1   2018 Q2          2
# 2   2018 Q3          3
# 3   2018 Q4          4
# 4   2019 Q1          5
# 5   2019 Q2          6
# 6   2019 Q3          7
# 7   2019 Q4          8
# 8   2020 Q1          9
# 9   2020 Q2         10
# 10  2020 Q3         11
# 11  2020 Q4         12
# 12  2021 Q1         13
# 13  2021 Q2         14
# 14  2021 Q3         15
# 15  2021 Q4         16

# %%
office4=office3.merge(df, left_on='Period',right_on='Period', how ='left')
retail4=retail3.merge(df, left_on='Period',right_on='Period', how ='left')
industry4=industry3.merge(df, left_on='Period',right_on='Period', how ='left')

# %%
#office4.to_csv('31_2_office_covid_2018-2021.csv',index=0)

#retail4.to_csv('32_2_retail_covid_2018-2021.csv',index=0)

#industry4.to_csv('33_2_industry_covid_2018-2021.csv',index=0)

# %% [markdown]
# # add facial mask and stay at home

# %% [markdown]
# ## merge data

# %%
mask=pd.read_excel('/Users/yoga/Dropbox/1 新冠和商业地产/101 CRE second time 202205/91_old_data_used for extracting facial mask and stay at home20220507.xlsx')
office4=pd.read_csv('/Users/yoga/Dropbox/1 新冠和商业地产/101 CRE second time 202205/31_2_office_covid_2018-2021.csv')
retail4=pd.read_csv('/Users/yoga/Dropbox/1 新冠和商业地产/101 CRE second time 202205/32_2_retail_covid_2018-2021.csv')
industry4=pd.read_csv('/Users/yoga/Dropbox/1 新冠和商业地产/101 CRE second time 202205/33_2_industry_covid_2018-2021.csv')

# %%
mask.columns.tolist()
# Out:
# ['Property Class Name',
#  'Period',
#  'Slice',
#  'As Of',
#  'Geography Name',
#  'CBSA Code',
#  'Property Type',
#  'Forecast Scenario',
#  'Geography Type',
#  'Geography Code',
#  'Appreciation Return',
#  'Asset Value',
#  'Availability Rate',
#  'Available SF',
#  'Average Sale Price',
#  'Cap Rate',
#  'Cap Rate Transactions',
#  'Capital Value Index',
#  'Demand SF',
#  'Demolished SF',
#  'Existing Buildings',
#  'Gross Delivered Buildings',
#  'Gross Delivered SF',
#  'Households',
#  'Income Return',
#  'Industrial Employment',
#  'Inventory SF',
#  'Leasing Activity SF',
#  'Market Cap Rate',
#  'Market Rent Growth',
#  'Market Rent Growth 12 Mo',
#  'Market Rent Index',
#  'Market Rent/SF',
#  'Market Sale Price Growth',
#  'Market Sale Price Index',
#  'Market Sale Price Per SF',
#  'Median Cap Rate',
#  'Median Household Income',
#  'Median Price/Bldg SF',
#  'Net Absorption SF',
#  'Net Absorption SF 12 Mo',
#  'Net Absorption SF Direct',
#  'Net Absorption SF Sublet',
#  'Net Delivered SF',
#  'Net Delivered SF 12 Mo',
#  'NOI Index',
#  'Occupancy Rate',
#  'Office Base Rent Direct',
#  'Office Base Rent Overall',
#  'Office Base Rent Sublet',
#  'Office Employment',
#  'Office Gross Rent Direct',
#  'Office Gross Rent Overall',
#  'Office Gross Rent Sublet',
#  'Population',
#  'Sales Volume Transactions',
#  'Sold Building SF',
#  'Total Employment',
#  'Total Return',
#  'Total Sales Volume',
#  'Transaction Sale Price/SF',
#  'Under Construction Buildings',
#  'Under Construction SF',
#  'Vacancy Rate',
#  'Vacant Available %',
#  'Vacant Available SF',
#  'Property Class Name.1',
#  'Period_x',
#  'Geography Name_x',
#  'CBSA Code.1',
#  'Households.1',
#  'Population.1',
#  'Industrial Employment.1',
#  'Office Employment.1',
#  'Total Employment.1',
#  'Market Rent Growth.1',
#  'Market Sale Price Growth.1',
#  'Sales Volume Transactions.1',
#  'Median Household Income.1',
#  '2020 percentage of vote for trump',
#  '2016 percentage of vote for trump',
#  'case in current quarter',
#  'death in current quarter',
#  'case in last quarter',
#  'death in last quarter',
#  '2018 CBSA GDP',
#  'ln 2018 CBSA GDP',
#  'CBSA_Population2010',
#  'ln CBSA_Population2010',
#  'Overall_CBSA_Population_density2010',
#  'Non-HispanicWhite alone:Percent of population 2010 CBSA',
#  'Hispanic or Latino:Percent of population 2010 CBSA',
#  'Black orAfrican AmericanOne race Percent of population  2010 CBSA',
#  'Asian_One race:Percent of population 2010 CBSA',
#  'male population Percent in 2010 CBSA',
#  'Median age, 2010 CBSA',
#  'Q2',
#  'Q3',
#  'Q4',
#  'percentage_stay at home',
#  'percentage_facial mask',
#  'lnCOVID-19 case current quarter',
#  'lnCOVID-19 death current quarter',
#  'lnCOVID-19 case last quarter',
#  'lnCOVID-19 death last quarter',
#  'ln Households',
#  'ln Industrial Employment',
#  'ln Office Employment',
#  'ln Total Employment',
#  'ln Median Household Income']

# %%
mask2=mask[['Period','CBSA Code','percentage_stay at home','percentage_facial mask']]

mask2['quarter_CBSAFP']=mask2['Period'].astype(str)+"&"+mask2['CBSA Code'].astype(int).astype(str)

mask2
# Out:
# <ipython-input-239-444b926b4fdb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mask2['quarter_CBSAFP']=mask2['Period'].astype(str)+"&"+mask2['CBSA Code'].astype(int).astype(str)
#       Period  CBSA Code  percentage_stay at home  percentage_facial mask  \
# 0    2019 Q1      19660                      NaN                     NaN
# 1    2019 Q2      19660                      NaN                     NaN
# 2    2019 Q3      19660                      NaN                     NaN
# 3    2019 Q4      19660                      NaN                     NaN
# 4    2020 Q1      19660                      0.0                     0.0
# ..       ...        ...                      ...                     ...
# 187  2019 Q4      45540                      NaN                     NaN
# 188  2020 Q1      45540                      0.0                     0.0
# 189  2020 Q2      45540                      0.0                     0.0
# 190  2020 Q3      45540                      0.0                     0.0
# 191  2020 Q4      45540                      0.0                     0.0
#
#     quarter_CBSAFP
# 0    2019 Q1&19660
# 1    2019 Q2&19660
# 2    2019 Q3&19660
# 3    2019 Q4&19660
# 4    2020 Q1&19660
# ..             ...
# 187  2019 Q4&45540
# 188  2020 Q1&45540
# 189  2020 Q2&45540
# 190  2020 Q3&45540
# 191  2020 Q4&45540
#
# [192 rows x 5 columns]

# %%
mask3=mask2[['percentage_stay at home','percentage_facial mask','quarter_CBSAFP']]
mask3
# Out:
#      percentage_stay at home  percentage_facial mask quarter_CBSAFP
# 0                        NaN                     NaN  2019 Q1&19660
# 1                        NaN                     NaN  2019 Q2&19660
# 2                        NaN                     NaN  2019 Q3&19660
# 3                        NaN                     NaN  2019 Q4&19660
# 4                        0.0                     0.0  2020 Q1&19660
# ..                       ...                     ...            ...
# 187                      NaN                     NaN  2019 Q4&45540
# 188                      0.0                     0.0  2020 Q1&45540
# 189                      0.0                     0.0  2020 Q2&45540
# 190                      0.0                     0.0  2020 Q3&45540
# 191                      0.0                     0.0  2020 Q4&45540
#
# [192 rows x 3 columns]

# %%
mask3.describe()
# Out:
#        percentage_stay at home  percentage_facial mask
# count                96.000000               96.000000
# mean                 19.763423               26.148626
# std                  38.725825               40.760137
# min                   0.000000                0.000000
# 25%                   0.000000                0.000000
# 50%                   0.000000                0.000000
# 75%                   6.868132               47.009348
# max                 100.000000              100.000000

# %%
#merge mask into office retail and industry

office5=office4.merge(mask3, left_on='quarter_CBSAFP',right_on='quarter_CBSAFP', how ='left')
retail5=retail4.merge(mask3, left_on='quarter_CBSAFP',right_on='quarter_CBSAFP', how ='left')
industry5=industry4.merge(mask3, left_on='quarter_CBSAFP',right_on='quarter_CBSAFP', how ='left')

# %%
#fill nan with 0
office5.update(office5[['percentage_stay at home','percentage_facial mask']].fillna(0))
retail5.update(retail5[['percentage_stay at home','percentage_facial mask']].fillna(0))
industry5.update(industry5[['percentage_stay at home','percentage_facial mask']].fillna(0))

# %% [markdown]
# # add quarterly dummy variable

# %%
#add quarter dummy variables
dummies=pd.get_dummies(office5['Period']).rename(columns=lambda x: 'Period'+str(x))

office6=pd.concat([office5,dummies],axis=1)

#plan to add quarterly column
office6.loc[:,'Q1']=office6.loc[:,'Period2018 Q1'].add(office6.loc[:,'Period2019 Q1']).add(office6.loc[:,'Period2020 Q1']).add(office6.loc[:,'Period2021 Q1'])

office6.loc[:,'Q2']=office6.loc[:,'Period2018 Q2'].add(office6.loc[:,'Period2019 Q2']).add(office6.loc[:,'Period2020 Q2']).add(office6.loc[:,'Period2021 Q2'])

office6.loc[:,'Q3']=office6.loc[:,'Period2018 Q3'].add(office6.loc[:,'Period2019 Q3']).add(office6.loc[:,'Period2020 Q3']).add(office6.loc[:,'Period2021 Q3'])

office6.loc[:,'Q4']=office6.loc[:,'Period2018 Q4'].add(office6.loc[:,'Period2019 Q4']).add(office6.loc[:,'Period2020 Q4']).add(office6.loc[:,'Period2021 Q4'])

# %%
#same to retail
#add quarter dummy variables
dummies=pd.get_dummies(retail5['Period']).rename(columns=lambda x: 'Period'+str(x))

retail6=pd.concat([retail5,dummies],axis=1)

#plan to add quarterly column
retail6.loc[:,'Q1']=retail6.loc[:,'Period2018 Q1'].add(retail6.loc[:,'Period2019 Q1']).add(retail6.loc[:,'Period2020 Q1']).add(retail6.loc[:,'Period2021 Q1'])

retail6.loc[:,'Q2']=retail6.loc[:,'Period2018 Q2'].add(retail6.loc[:,'Period2019 Q2']).add(retail6.loc[:,'Period2020 Q2']).add(retail6.loc[:,'Period2021 Q2'])

retail6.loc[:,'Q3']=retail6.loc[:,'Period2018 Q3'].add(retail6.loc[:,'Period2019 Q3']).add(retail6.loc[:,'Period2020 Q3']).add(retail6.loc[:,'Period2021 Q3'])

retail6.loc[:,'Q4']=retail6.loc[:,'Period2018 Q4'].add(retail6.loc[:,'Period2019 Q4']).add(retail6.loc[:,'Period2020 Q4']).add(retail6.loc[:,'Period2021 Q4'])

# %%
#same to industry

dummies=pd.get_dummies(industry5['Period']).rename(columns=lambda x: 'Period'+str(x))

industry6=pd.concat([industry5,dummies],axis=1)

#plan to add quarterly column
industry6.loc[:,'Q1']=industry6.loc[:,'Period2018 Q1'].add(industry6.loc[:,'Period2019 Q1']).add(industry6.loc[:,'Period2020 Q1']).add(industry6.loc[:,'Period2021 Q1'])

industry6.loc[:,'Q2']=industry6.loc[:,'Period2018 Q2'].add(industry6.loc[:,'Period2019 Q2']).add(industry6.loc[:,'Period2020 Q2']).add(industry6.loc[:,'Period2021 Q2'])

industry6.loc[:,'Q3']=industry6.loc[:,'Period2018 Q3'].add(industry6.loc[:,'Period2019 Q3']).add(industry6.loc[:,'Period2020 Q3']).add(industry6.loc[:,'Period2021 Q3'])

industry6.loc[:,'Q4']=industry6.loc[:,'Period2018 Q4'].add(industry6.loc[:,'Period2019 Q4']).add(industry6.loc[:,'Period2020 Q4']).add(industry6.loc[:,'Period2021 Q4'])

# %%
#office6.to_csv('31_3_office_covid_2018-2021.csv',index=0)

#retail6.to_csv('32_3_retail_covid_2018-2021.csv',index=0)

#industry6.to_csv('33_3_industry_covid_2018-2021.csv',index=0)

# %% [markdown]
# # add the one quarter lag covid data

# %%
office6=pd.read_csv('/Users/yoga/Dropbox/1 新冠和商业地产/101 CRE second time 202205/31_3_office_covid_2018-2021.csv')
retail6=pd.read_csv('/Users/yoga/Dropbox/1 新冠和商业地产/101 CRE second time 202205/32_3_retail_covid_2018-2021.csv')
industry6=pd.read_csv('/Users/yoga/Dropbox/1 新冠和商业地产/101 CRE second time 202205/33_3_industry_covid_2018-2021.csv')

# %%
office6.columns.tolist()
# Out:
# ['Property Class Name',
#  'Period',
#  'Slice',
#  'As Of',
#  'Geography Name',
#  'CBSA Code',
#  'Property Type',
#  'Forecast Scenario',
#  'Geography Type',
#  'Geography Code',
#  'Appreciation Return',
#  'Asset Value',
#  'Availability Rate',
#  'Available SF',
#  'Average Sale Price',
#  'Cap Rate',
#  'Cap Rate Transactions',
#  'Capital Value Index',
#  'Demand SF',
#  'Demolished SF',
#  'Existing Buildings',
#  'Gross Delivered Buildings',
#  'Gross Delivered SF',
#  'Households',
#  'Income Return',
#  'Industrial Employment',
#  'Inventory SF',
#  'Leasing Activity SF',
#  'Market Cap Rate',
#  'Market Rent Growth',
#  'Market Rent Growth 12 Mo',
#  'Market Rent Index',
#  'Market Rent/SF',
#  'Market Sale Price Growth',
#  'Market Sale Price Index',
#  'Market Sale Price Per SF',
#  'Median Cap Rate',
#  'Median Household Income',
#  'Median Price/Bldg SF',
#  'Net Absorption SF',
#  'Net Absorption SF 12 Mo',
#  'Net Absorption SF Direct',
#  'Net Absorption SF Sublet',
#  'Net Delivered SF',
#  'Net Delivered SF 12 Mo',
#  'NOI Index',
#  'Occupancy Rate',
#  'Office Base Rent Direct',
#  'Office Base Rent Overall',
#  'Office Base Rent Sublet',
#  'Office Employment',
#  'Office Gross Rent Direct',
#  'Office Gross Rent Overall',
#  'Office Gross Rent Sublet',
#  'Population',
#  'Sales Volume Transactions',
#  'Sold Building SF',
#  'Total Employment',
#  'Total Return',
#  'Total Sales Volume',
#  'Transaction Sale Price/SF',
#  'Under Construction Buildings',
#  'Under Construction SF',
#  'Vacancy Rate',
#  'Vacant Available %',
#  'Vacant Available SF',
#  'quarter_CBSAFP',
#  'quarter_cbsa',
#  'current_case',
#  'current_death',
#  'ln_cases_current',
#  'ln_death_current',
#  'TimeIndex',
#  'percentage_stay at home',
#  'percentage_facial mask',
#  'Period2018 Q1',
#  'Period2018 Q2',
#  'Period2018 Q3',
#  'Period2018 Q4',
#  'Period2019 Q1',
#  'Period2019 Q2',
#  'Period2019 Q3',
#  'Period2019 Q4',
#  'Period2020 Q1',
#  'Period2020 Q2',
#  'Period2020 Q3',
#  'Period2020 Q4',
#  'Period2021 Q1',
#  'Period2021 Q2',
#  'Period2021 Q3',
#  'Period2021 Q4',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Q4']

# %%
lncovid=office6[['Period','CBSA Code','ln_cases_current','ln_death_current']]
lncovid
# Out:
#       Period  CBSA Code  ln_cases_current  ln_death_current
# 0    2018 Q1      19660          0.000000          0.000000
# 1    2018 Q2      19660          0.000000          0.000000
# 2    2018 Q3      19660          0.000000          0.000000
# 3    2018 Q4      19660          0.000000          0.000000
# 4    2019 Q1      19660          0.000000          0.000000
# ..       ...        ...               ...               ...
# 379  2020 Q4      45540          7.927324          3.912023
# 380  2021 Q1      45540          8.217439          4.919981
# 381  2021 Q2      45540          6.586172          3.295837
# 382  2021 Q3      45540          8.406262          4.969813
# 383  2021 Q4      45540          7.254885          3.850148
#
# [384 rows x 4 columns]

# %%
#目标是产生下一期的时间序列，然后合并到cbsa code, 然后和表格进行merge，就可以了。
period=office6['Period'].unique().tolist()
period
# Out:
# ['2018 Q1',
#  '2018 Q2',
#  '2018 Q3',
#  '2018 Q4',
#  '2019 Q1',
#  '2019 Q2',
#  '2019 Q3',
#  '2019 Q4',
#  '2020 Q1',
#  '2020 Q2',
#  '2020 Q3',
#  '2020 Q4',
#  '2021 Q1',
#  '2021 Q2',
#  '2021 Q3',
#  '2021 Q4']

# %%
period[1][-1]
# Out:
# '2'

# %%
period2next={}
for i in range(len(period)):
    qi=period[i][-1]
    if qi!="4":
        period2next[period[i]]=period[i][:6]+str(int(qi)+1)
    else:
        period2next[period[i]]='20'+str(int(period[i][2:4])+1)+" Q1"

# %%
period2next
# Out:
# {'2018 Q1': '2018 Q2',
#  '2018 Q2': '2018 Q3',
#  '2018 Q3': '2018 Q4',
#  '2018 Q4': '2019 Q1',
#  '2019 Q1': '2019 Q2',
#  '2019 Q2': '2019 Q3',
#  '2019 Q3': '2019 Q4',
#  '2019 Q4': '2020 Q1',
#  '2020 Q1': '2020 Q2',
#  '2020 Q2': '2020 Q3',
#  '2020 Q3': '2020 Q4',
#  '2020 Q4': '2021 Q1',
#  '2021 Q1': '2021 Q2',
#  '2021 Q2': '2021 Q3',
#  '2021 Q3': '2021 Q4',
#  '2021 Q4': '2022 Q1'}

# %%
pd_period2next = pd.DataFrame(list(period2next.items()),columns = ['current', 'next'])

# %%
lncovid2=lncovid.merge(pd_period2next,left_on='Period',right_on='current',how='left')
lncovid2
# Out:
#       Period  CBSA Code  ln_cases_current  ln_death_current  current     next
# 0    2018 Q1      19660          0.000000          0.000000  2018 Q1  2018 Q2
# 1    2018 Q2      19660          0.000000          0.000000  2018 Q2  2018 Q3
# 2    2018 Q3      19660          0.000000          0.000000  2018 Q3  2018 Q4
# 3    2018 Q4      19660          0.000000          0.000000  2018 Q4  2019 Q1
# 4    2019 Q1      19660          0.000000          0.000000  2019 Q1  2019 Q2
# ..       ...        ...               ...               ...      ...      ...
# 379  2020 Q4      45540          7.927324          3.912023  2020 Q4  2021 Q1
# 380  2021 Q1      45540          8.217439          4.919981  2021 Q1  2021 Q2
# 381  2021 Q2      45540          6.586172          3.295837  2021 Q2  2021 Q3
# 382  2021 Q3      45540          8.406262          4.969813  2021 Q3  2021 Q4
# 383  2021 Q4      45540          7.254885          3.850148  2021 Q4  2022 Q1
#
# [384 rows x 6 columns]

# %%
lncovid2['nest_quarter_CBSAFP']=lncovid2['next'].astype(str)+"&"+lncovid2['CBSA Code'].astype(int).astype(str)
# Out:
#       Period  CBSA Code  ln_cases_current  ln_death_current  current     next  \
# 0    2018 Q1      19660          0.000000          0.000000  2018 Q1  2018 Q2
# 1    2018 Q2      19660          0.000000          0.000000  2018 Q2  2018 Q3
# 2    2018 Q3      19660          0.000000          0.000000  2018 Q3  2018 Q4
# 3    2018 Q4      19660          0.000000          0.000000  2018 Q4  2019 Q1
# 4    2019 Q1      19660          0.000000          0.000000  2019 Q1  2019 Q2
# ..       ...        ...               ...               ...      ...      ...
# 379  2020 Q4      45540          7.927324          3.912023  2020 Q4  2021 Q1
# 380  2021 Q1      45540          8.217439          4.919981  2021 Q1  2021 Q2
# 381  2021 Q2      45540          6.586172          3.295837  2021 Q2  2021 Q3
# 382  2021 Q3      45540          8.406262          4.969813  2021 Q3  2021 Q4
# 383  2021 Q4      45540          7.254885          3.850148  2021 Q4  2022 Q1
#
#     nest_quarter_CBSAFP
# 0         2018 Q2&19660
# 1         2018 Q3&19660
# 2         2018 Q4&19660
# 3         2019 Q1&19660
# 4         2019 Q2&19660
# ..                  ...
# 379       2021 Q1&45540
# 380       2021 Q2&45540
# 381       2021 Q3&45540
# 382       2021 Q4&45540
# 383       2022 Q1&45540
#
# [384 rows x 7 columns]

# %%
lncovid3=lncovid2[['nest_quarter_CBSAFP','ln_cases_current','ln_death_current']]

lncovid3=lncovid3.rename(columns={"ln_cases_current": "ln_cases_prior", "ln_death_current": "ln_death_prior"})

lncovid3
# Out:
#     nest_quarter_CBSAFP  ln_cases_prior  ln_death_prior
# 0         2018 Q2&19660        0.000000        0.000000
# 1         2018 Q3&19660        0.000000        0.000000
# 2         2018 Q4&19660        0.000000        0.000000
# 3         2019 Q1&19660        0.000000        0.000000
# 4         2019 Q2&19660        0.000000        0.000000
# ..                  ...             ...             ...
# 379       2021 Q1&45540        7.927324        3.912023
# 380       2021 Q2&45540        8.217439        4.919981
# 381       2021 Q3&45540        6.586172        3.295837
# 382       2021 Q4&45540        8.406262        4.969813
# 383       2022 Q1&45540        7.254885        3.850148
#
# [384 rows x 3 columns]

# %%
#然后用next quarter cbsa fp作为key merge 到原来的数据里。
office7=office6.merge(lncovid3,left_on='quarter_CBSAFP',right_on='nest_quarter_CBSAFP',how='left')

retail7=retail6.merge(lncovid3,left_on='quarter_CBSAFP',right_on='nest_quarter_CBSAFP',how='left')

industry7=industry6.merge(lncovid3,left_on='quarter_CBSAFP',right_on='nest_quarter_CBSAFP',how='left')

# %%
#检查通过没有问题
#industry7 retail7 office7
retail7[['Period',
 'Geography Name',
 'CBSA Code','ln_cases_current','ln_cases_prior','ln_death_current','ln_death_prior']].tail(10)
# Out:
#       Period     Geography Name  CBSA Code  ln_cases_current  ln_cases_prior  \
# 374  2019 Q3  The Villages - FL      45540          0.000000        0.000000
# 375  2019 Q4  The Villages - FL      45540          0.000000        0.000000
# 376  2020 Q1  The Villages - FL      45540          3.931826        0.000000
# 377  2020 Q2  The Villages - FL      45540          5.683580        3.931826
# 378  2020 Q3  The Villages - FL      45540          7.584773        5.683580
# 379  2020 Q4  The Villages - FL      45540          7.927324        7.584773
# 380  2021 Q1  The Villages - FL      45540          8.217439        7.927324
# 381  2021 Q2  The Villages - FL      45540          6.586172        8.217439
# 382  2021 Q3  The Villages - FL      45540          8.406262        6.586172
# 383  2021 Q4  The Villages - FL      45540          7.254885        8.406262
#
#      ln_death_current  ln_death_prior
# 374          0.000000        0.000000
# 375          0.000000        0.000000
# 376          0.000000        0.000000
# 377          2.833213        0.000000
# 378          3.970292        2.833213
# 379          3.912023        3.970292
# 380          4.919981        3.912023
# 381          3.295837        4.919981
# 382          4.969813        3.295837
# 383          3.850148        4.969813

# %%
industry7[['ln_cases_prior','ln_death_prior']] = industry7[['ln_cases_prior','ln_death_prior']].fillna(0)

retail7[['ln_cases_prior','ln_death_prior']] = retail7[['ln_cases_prior','ln_death_prior']].fillna(0)

office7[['ln_cases_prior','ln_death_prior']] = office7[['ln_cases_prior','ln_death_prior']].fillna(0)

# %%
#office7.to_csv('31_4_office_covid_2018-2021.csv',index=0)

#retail7.to_csv('32_4_retail_covid_2018-2021.csv',index=0)

#industry7.to_csv('33_4_industry_covid_2018-2021.csv',index=0)

# %% [markdown]
# # calculate correlation

# %%
retail=pd.read_csv('/Users/yoga/Dropbox/1 新冠和商业地产/101 CRE second time 202205/32_4_retail_covid_2018-2021.csv')

# %%
retail.columns
# Out:
# Index(['Property Class Name', 'Period', 'Slice', 'As Of', 'Geography Name',
#        'CBSA Code', 'Property Type', 'Forecast Scenario', 'Geography Type',
#        'Geography Code', 'All Service Type Rent Direct',
#        'All Service Type Rent Overall', 'All Service Type Rent Sublet',
#        'Appreciation Return', 'Asset Value', 'Availability Rate',
#        'Available SF', 'Average Sale Price', 'Cap Rate',
#        'Cap Rate Transactions', 'Capital Value Index', 'Demand SF',
#        'Demolished SF', 'Existing Buildings', 'Existing Centers',
#        'Gross Delivered Buildings', 'Gross Delivered SF', 'Households',
#        'Income Return', 'Industrial Employment', 'Inventory SF',
#        'Leasing Activity SF', 'Market Cap Rate', 'Market Rent Growth',
#        'Market Rent Growth 12 Mo', 'Market Rent Index', 'Market Rent/SF',
#        'Market Sale Price Growth', 'Market Sale Price Index',
#        'Market Sale Price Per SF', 'Median Cap Rate',
#        'Median Household Income', 'Median Price/Bldg SF', 'Net Absorption SF',
#        'Net Absorption SF 12 Mo', 'Net Absorption SF Direct',
#        'Net Absorption SF Sublet', 'Net Delivered SF',
#        'Net Delivered SF 12 Mo', 'NNN Rent Direct', 'NNN Rent Overall',
#        'NNN Rent Sublet', 'NOI Index', 'Occupancy Rate', 'Office Employment',
#        'Population', 'Sales Volume Transactions', 'Sold Building SF',
#        'Total Employment', 'Total Return', 'Total Sales Volume',
#        'Transaction Sale Price/SF', 'Under Construction Buildings',
#        'Under Construction SF', 'Vacancy Rate', 'Vacant Available %',
#        'Vacant Available SF', 'quarter_CBSAFP', 'quarter_cbsa', 'current_case',
#        'current_death', 'ln_cases_current', 'ln_death_current', 'TimeIndex',
#        'percentage_stay at home', 'percentage_facial mask', 'Period2018 Q1',
#        'Period2018 Q2', 'Period2018 Q3', 'Period2018 Q4', 'Period2019 Q1',
#        'Period2019 Q2', 'Period2019 Q3', 'Period2019 Q4', 'Period2020 Q1',
#        'Period2020 Q2', 'Period2020 Q3', 'Period2020 Q4', 'Period2021 Q1',
#        'Period2021 Q2', 'Period2021 Q3', 'Period2021 Q4', 'Q1', 'Q2', 'Q3',
#        'Q4', 'nest_quarter_CBSAFP', 'ln_cases_prior', 'ln_death_prior'],
#       dtype='object')

# %%
retail_cor=retail[['ln_cases_current', 'ln_cases_prior', 'ln_death_current','ln_death_prior',
                   'Total Employment','percentage_stay at home', 'percentage_facial mask']]

# %%
retail_cor
# Out:
#      ln_cases_current  ln_cases_prior  ln_death_current  ln_death_prior  \
# 0            0.000000        0.000000          0.000000        0.000000
# 1            0.000000        0.000000          0.000000        0.000000
# 2            0.000000        0.000000          0.000000        0.000000
# 3            0.000000        0.000000          0.000000        0.000000
# 4            0.000000        0.000000          0.000000        0.000000
# ..                ...             ...               ...             ...
# 379          7.927324        7.584773          3.912023        3.970292
# 380          8.217439        7.927324          4.919981        3.912023
# 381          6.586172        8.217439          3.295837        4.919981
# 382          8.406262        6.586172          4.969813        3.295837
# 383          7.254885        8.406262          3.850148        4.969813
#
#      Total Employment  percentage_stay at home  percentage_facial mask
# 0       202634.593750                      0.0                     0.0
# 1       203406.906250                      0.0                     0.0
# 2       204901.390625                      0.0                     0.0
# 3       205294.500000                      0.0                     0.0
# 4       205313.906250                      0.0                     0.0
# ..                ...                      ...                     ...
# 379      31842.000000                      0.0                     0.0
# 380      31496.189453                      0.0                     0.0
# 381      31540.269531                      0.0                     0.0
# 382      31965.048828                      0.0                     0.0
# 383      32531.201172                      0.0                     0.0
#
# [384 rows x 7 columns]

# %%
corrMatrix = retail_cor.corr()

# %%
corrMatrix
# Out:
#                          ln_cases_current  ln_cases_prior  ln_death_current  \
# ln_cases_current                 1.000000        0.929994          0.973075
# ln_cases_prior                   0.929994        1.000000          0.956173
# ln_death_current                 0.973075        0.956173          1.000000
# ln_death_prior                   0.876552        0.972408          0.913185
# Total Employment                 0.106457        0.092816          0.137557
# percentage_stay at home          0.279194        0.216451          0.267302
# percentage_facial mask           0.343981        0.315155          0.347986
#
#                          ln_death_prior  Total Employment  \
# ln_cases_current               0.876552          0.106457
# ln_cases_prior                 0.972408          0.092816
# ln_death_current               0.913185          0.137557
# ln_death_prior                 1.000000          0.129157
# Total Employment               0.129157          1.000000
# percentage_stay at home        0.159154          0.182648
# percentage_facial mask         0.280199          0.161612
#
#                          percentage_stay at home  percentage_facial mask
# ln_cases_current                        0.279194                0.343981
# ln_cases_prior                          0.216451                0.315155
# ln_death_current                        0.267302                0.347986
# ln_death_prior                          0.159154                0.280199
# Total Employment                        0.182648                0.161612
# percentage_stay at home                 1.000000                0.651636
# percentage_facial mask                  0.651636                1.000000

# %%
#corrMatrix.to_csv('399_correlation_appendix_in_paper.csv')

# %%
retail_cor['Million_emp']=retail_cor['Total Employment']/1000000
describe=retail_cor.describe()
# Out:
# <ipython-input-23-a8b10cdac90f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   retail_cor['Million_emp']=retail_cor['Total Employment']/1000000

# %%
#describe.to_csv('398_correlation_describe.csv')

# %%
retail_cor.corr()
# Out:
#                          ln_cases_current  ln_cases_prior  ln_death_current  \
# ln_cases_current                 1.000000        0.929994          0.973075
# ln_cases_prior                   0.929994        1.000000          0.956173
# ln_death_current                 0.973075        0.956173          1.000000
# ln_death_prior                   0.876552        0.972408          0.913185
# Total Employment                 0.106457        0.092816          0.137557
# percentage_stay at home          0.279194        0.216451          0.267302
# percentage_facial mask           0.343981        0.315155          0.347986
# Million_emp                      0.106457        0.092816          0.137557
#
#                          ln_death_prior  Total Employment  \
# ln_cases_current               0.876552          0.106457
# ln_cases_prior                 0.972408          0.092816
# ln_death_current               0.913185          0.137557
# ln_death_prior                 1.000000          0.129157
# Total Employment               0.129157          1.000000
# percentage_stay at home        0.159154          0.182648
# percentage_facial mask         0.280199          0.161612
# Million_emp                    0.129157          1.000000
#
#                          percentage_stay at home  percentage_facial mask  \
# ln_cases_current                        0.279194                0.343981
# ln_cases_prior                          0.216451                0.315155
# ln_death_current                        0.267302                0.347986
# ln_death_prior                          0.159154                0.280199
# Total Employment                        0.182648                0.161612
# percentage_stay at home                 1.000000                0.651636
# percentage_facial mask                  0.651636                1.000000
# Million_emp                             0.182648                0.161612
#
#                          Million_emp
# ln_cases_current            0.106457
# ln_cases_prior              0.092816
# ln_death_current            0.137557
# ln_death_prior              0.129157
# Total Employment            1.000000
# percentage_stay at home     0.182648
# percentage_facial mask      0.161612
# Million_emp                 1.000000

# %%
# Out:
#        ln_cases_current  ln_cases_prior  ln_death_current  ln_death_prior  \
# count        384.000000      384.000000        384.000000      384.000000
# mean           4.286741        3.712482          2.335957        1.996656
# std            4.560674        4.471949          2.694712        2.615021
# min            0.000000        0.000000          0.000000        0.000000
# 25%            0.000000        0.000000          0.000000        0.000000
# 50%            0.000000        0.000000          0.000000        0.000000
# 75%            9.054283        8.657080          5.051362        4.738382
# max           12.159678       12.118852          7.796058        7.796058
#
#        Total Employment  percentage_stay at home  percentage_facial mask  \
# count      3.840000e+02               384.000000              384.000000
# mean       3.571100e+05                 4.940856                6.537156
# std        4.048860e+05                21.104811               23.251490
# min        2.402740e+04                 0.000000                0.000000
# 25%        9.797862e+04                 0.000000                0.000000
# 50%        1.844490e+05                 0.000000                0.000000
# 75%        3.835281e+05                 0.000000                0.000000
# max        1.415920e+06               100.000000              100.000000
#
#        Million_emp
# count   384.000000
# mean      0.357110
# std       0.404886
# min       0.024027
# 25%       0.097979
# 50%       0.184449
# 75%       0.383528
# max       1.415920

# %% [markdown]
# # number used in the paper

# %% [markdown]
# ## It has caused 824k deaths as of December 2021

# %%
covid=pd.read_csv('/Users/yoga/Documents/Projects/1_covid19_cre/72_update regression analysis 20220122/1_us-counties_covid20220122.csv')

# %%
covid2021=covid[covid['date']=='2021-12-31']

# %%
covid2021['deaths'].sum()
# Out:
# 824336.0

# %% [markdown]
# ## Florida is a state with the third largest accumulated number of COVID cases ( 4.17 million) in the U.S. in 2021

# %%
covid2021fl=covid2021.loc[covid2021['state']=='Florida']

# %%
covid2021fl['cases'].sum()
# Out:
# 4166392

# %% [markdown]
# ## The asset value of the commercial real estate industry reached 4 billion in the fourth quarter of 2021

# %%
office=pd.read_excel('/Users/yoga/Documents/Projects/1_covid19_cre/73_costar data 20220118/reupdatecostardatatoincludethewholeyearof2021/Office_01-18-2022.xlsx')
industry=pd.read_excel('/Users/yoga/Documents/Projects/1_covid19_cre/73_costar data 20220118/reupdatecostardatatoincludethewholeyearof2021/Industrial_01-18-2022.xlsx')
retail=pd.read_excel('/Users/yoga/Documents/Projects/1_covid19_cre/73_costar data 20220118/reupdatecostardatatoincludethewholeyearof2021/Retail_01-18-2022.xlsx')

# %%
retail1=retail[['Geography Name','Period','Asset Value']]
retail2=retail1[retail1['Period']=='2021 Q4']

retail3=retail2['Asset Value'].sum()
retail3
# Out:
# 280633485696.0

# %%
office1=office[['Geography Name','Period','Asset Value']]
office2=office1[office1['Period']=='2021 Q4']

office3=office2['Asset Value'].sum()
office3
# Out:
# 162607961792.0

# %%
industry1=industry[['Geography Name','Period','Asset Value']]
industry2=industry1[industry1['Period']=='2021 Q4']

industry3=industry2['Asset Value'].sum()
industry3
# Out:
# 180730644904.0

# %%
total=industry3+office3+retail3

# %%
total/1000000000
# Out:
# 623.972092392

# %% [markdown]
# ## Every one percent increase in COVID cases causes the retail vacancy rate to grow by 0.3 percent each quarter – about 352 thousand square feet.

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3864 entries, 0 to 3863
# Data columns (total 67 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Property Class Name            3864 non-null   object
#  1   Period                         3864 non-null   object
#  2   Slice                          3864 non-null   object
#  3   As Of                          3864 non-null   object
#  4   Geography Name                 3864 non-null   object
#  5   CBSA Code                      3864 non-null   int64
#  6   Property Type                  3864 non-null   object
#  7   Forecast Scenario              3864 non-null   object
#  8   Geography Type                 3864 non-null   object
#  9   Geography Code                 3864 non-null   object
#  10  All Service Type Rent Direct   1487 non-null   float64
#  11  All Service Type Rent Overall  1487 non-null   float64
#  12  All Service Type Rent Sublet   1176 non-null   float64
#  13  Appreciation Return            3047 non-null   float64
#  14  Asset Value                    3143 non-null   float64
#  15  Availability Rate              1463 non-null   float64
#  16  Available SF                   1487 non-null   float64
#  17  Average Sale Price             1459 non-null   float64
#  18  Cap Rate                       1218 non-null   float64
#  19  Cap Rate Transactions          1465 non-null   float64
#  20  Capital Value Index            3143 non-null   float64
#  21  Demand SF                      2063 non-null   float64
#  22  Demolished SF                  1484 non-null   float64
#  23  Existing Buildings             1487 non-null   float64
#  24  Existing Centers               1463 non-null   float64
#  25  Gross Delivered Buildings      1463 non-null   float64
#  26  Gross Delivered SF             1484 non-null   float64
#  27  Households                     3864 non-null   float64
#  28  Income Return                  3143 non-null   float64
#  29  Industrial Employment          3096 non-null   float64
#  30  Inventory SF                   3864 non-null   int64
#  31  Leasing Activity SF            1464 non-null   float64
#  32  Market Cap Rate                3143 non-null   float64
#  33  Market Rent Growth             1883 non-null   float64
#  34  Market Rent Growth 12 Mo       1811 non-null   float64
#  35  Market Rent Index              1907 non-null   float64
#  36  Market Rent/SF                 1907 non-null   float64
#  37  Market Sale Price Growth       1391 non-null   float64
#  38  Market Sale Price Index        3143 non-null   float64
#  39  Market Sale Price Per SF       1487 non-null   float64
#  40  Median Cap Rate                0 non-null      float64
#  41  Median Household Income        1584 non-null   float64
#  42  Median Price/Bldg SF           0 non-null      float64
#  43  Net Absorption SF              2038 non-null   float64
#  44  Net Absorption SF 12 Mo        1967 non-null   float64
#  45  Net Absorption SF Direct       1462 non-null   float64
#  46  Net Absorption SF Sublet       970 non-null    float64
#  47  Net Delivered SF               3840 non-null   float64
#  48  Net Delivered SF 12 Mo         3768 non-null   float64
#  49  NNN Rent Direct                1487 non-null   float64
#  50  NNN Rent Overall               1487 non-null   float64
#  51  NNN Rent Sublet                1090 non-null   float64
#  52  NOI Index                      3143 non-null   float64
#  53  Occupancy Rate                 2063 non-null   float64
#  54  Office Employment              3096 non-null   float64
#  55  Population                     3864 non-null   float64
#  56  Sales Volume Transactions      1465 non-null   float64
#  57  Sold Building SF               1465 non-null   float64
#  58  Total Employment               3096 non-null   float64
#  59  Total Return                   3047 non-null   float64
#  60  Total Sales Volume             1487 non-null   float64
#  61  Transaction Sale Price/SF      1459 non-null   float64
#  62  Under Construction Buildings   1463 non-null   float64
#  63  Under Construction SF          1424 non-null   float64
#  64  Vacancy Rate                   2063 non-null   float64
#  65  Vacant Available %             1463 non-null   float64
#  66  Vacant Available SF            1463 non-null   float64
# dtypes: float64(56), int64(2), object(9)
# memory usage: 2.0+ MB

# %%
#get the 2020 Q1 data
retail2=retail[retail['Period'].str.contains('2020 Q1')]
retail3=retail[retail['Period'].str.contains('2020 Q2')]
retail2
# Out:
#      Property Class Name   Period Slice    As Of             Geography Name  \
# 152               Retail  2020 Q1   All  2022 Q1         Daytona Beach - FL
# 313               Retail  2020 Q1   All  2022 Q1       Fort Lauderdale - FL
# 474               Retail  2020 Q1   All  2022 Q1            Fort Myers - FL
# 635               Retail  2020 Q1   All  2022 Q1       Ft Walton Beach - FL
# 796               Retail  2020 Q1   All  2022 Q1           Gainesville - FL
# 957               Retail  2020 Q1   All  2022 Q1     Homosassa Springs - FL
# 1118              Retail  2020 Q1   All  2022 Q1          Jacksonville - FL
# 1279              Retail  2020 Q1   All  2022 Q1              Lakeland - FL
# 1440              Retail  2020 Q1   All  2022 Q1             Melbourne - FL
# 1601              Retail  2020 Q1   All  2022 Q1                 Miami - FL
# 1762              Retail  2020 Q1   All  2022 Q1                Naples - FL
# 1923              Retail  2020 Q1   All  2022 Q1                 Ocala - FL
# 2084              Retail  2020 Q1   All  2022 Q1               Orlando - FL
# 2245              Retail  2020 Q1   All  2022 Q1            Palm Beach - FL
# 2406              Retail  2020 Q1   All  2022 Q1           Panama City - FL
# 2567              Retail  2020 Q1   All  2022 Q1             Pensacola - FL
# 2728              Retail  2020 Q1   All  2022 Q1        Port St. Lucie - FL
# 2889              Retail  2020 Q1   All  2022 Q1           Punta Gorda - FL
# 3050              Retail  2020 Q1   All  2022 Q1              Sarasota - FL
# 3211              Retail  2020 Q1   All  2022 Q1  Sebastian-Vero Beach - FL
# 3372              Retail  2020 Q1   All  2022 Q1               Sebring - FL
# 3533              Retail  2020 Q1   All  2022 Q1           Tallahassee - FL
# 3694              Retail  2020 Q1   All  2022 Q1                 Tampa - FL
# 3855              Retail  2020 Q1   All  2022 Q1          The Villages - FL
#
#       CBSA Code Property Type Forecast Scenario Geography Type Geography Code  \
# 152       19660        Retail         Base Case          Metro         G41649
# 313       22744        Retail         Base Case          Metro         G41715
# 474       15980        Retail         Base Case          Metro         G41609
# 635       18880        Retail         Base Case          Metro         G41639
# 796       23540        Retail         Base Case          Metro         G41743
# 957       26140        Retail         Base Case          Metro         G41804
# 1118      27260        Retail         Base Case          Metro         G41817
# 1279      29460        Retail         Base Case          Metro         G39424
# 1440      37340        Retail         Base Case          Metro         G39499
# 1601      33124        Retail         Base Case          Metro         G39457
# 1762      34940        Retail         Base Case          Metro         G39476
# 1923      36100        Retail         Base Case          Metro         G39488
# 2084      36740        Retail         Base Case          Metro         G39495
# 2245      48424        Retail         Base Case          Metro         G39605
# 2406      37460        Retail         Base Case          Metro         G39500
# 2567      37860        Retail         Base Case          Metro         G39502
# 2728      38940        Retail         Base Case          Metro         G39512
# 2889      39460        Retail         Base Case          Metro         G39517
# 3050      35840        Retail         Base Case          Metro         G39485
# 3211      42680        Retail         Base Case          Metro         G39556
# 3372      42700        Retail         Base Case          Metro         G39557
# 3533      45220        Retail         Base Case          Metro         G39576
# 3694      45300        Retail         Base Case          Metro         G39577
# 3855      45540        Retail         Base Case          Metro         G39580
#
#       ...  Sold Building SF  Total Employment  Total Return  \
# 152   ...          567655.0      2.076436e+05      0.092421
# 313   ...          721566.0      8.713660e+05      0.069432
# 474   ...          857931.0      2.806959e+05      0.072605
# 635   ...          247256.0      1.196070e+05      0.069466
# 796   ...          190624.0      1.486744e+05      0.057596
# 957   ...           77264.0      3.320562e+04      0.075378
# 1118  ...          787557.0      7.319252e+05      0.090172
# 1279  ...          410747.0      2.413164e+05      0.077058
# 1440  ...          255452.0      2.339077e+05      0.084913
# 1601  ...          774827.0      1.227054e+06      0.061674
# 1762  ...          161809.0      1.566170e+05      0.048812
# 1923  ...          240810.0      1.094951e+05      0.060625
# 2084  ...         1885823.0      1.340572e+06      0.091379
# 2245  ...          667428.0      6.462659e+05      0.073972
# 2406  ...          157774.0      8.192945e+04      0.051401
# 2567  ...          299672.0      1.884878e+05      0.057898
# 2728  ...          352956.0      1.575515e+05      0.065455
# 2889  ...          184650.0      5.035907e+04      0.091477
# 3050  ...          687464.0      3.143020e+05      0.061450
# 3211  ...           80337.0      5.473087e+04      0.041938
# 3372  ...          107727.0      2.576355e+04      0.071466
# 3533  ...          144227.0      1.868191e+05      0.057665
# 3694  ...         1950506.0      1.404281e+06      0.108211
# 3855  ...           23961.0      3.280515e+04      0.061790
#
#       Total Sales Volume  Transaction Sale Price/SF  \
# 152           86575872.0                     161.15
# 313          162616624.0                     278.63
# 474           91193224.0                     111.94
# 635            8625300.0                     126.14
# 796           12316000.0                     104.60
# 957            6597843.0                     109.20
# 1118         126094592.0                     165.75
# 1279          48159796.0                     131.83
# 1440          41828464.0                     193.30
# 1601         175010416.0                     261.18
# 1762          51608832.0                     336.57
# 1923          34945712.0                     149.97
# 2084         202806128.0                     186.48
# 2245         187616736.0                     306.55
# 2406          12240200.0                     103.49
# 2567          33108394.0                     141.40
# 2728          58138720.0                     181.17
# 2889          27836470.0                     160.99
# 3050          63475836.0                     103.47
# 3211          12885092.0                     175.13
# 3372           3572000.0                      41.87
# 3533          29208400.0                     237.18
# 3694         313957856.0                     183.41
# 3855           3020050.0                     147.59
#
#       Under Construction Buildings  Under Construction SF  Vacancy Rate  \
# 152                            7.0               148897.0      0.043260
# 313                           45.0               913417.0      0.042585
# 474                           25.0               298268.0      0.055938
# 635                            9.0               178006.0      0.025671
# 796                            7.0                65443.0      0.019187
# 957                            2.0                 6665.0      0.065337
# 1118                          66.0              1247215.0      0.045949
# 1279                          21.0               207633.0      0.035479
# 1440                          10.0               164677.0      0.054184
# 1601                          47.0              2184584.0      0.039201
# 1762                           8.0               159173.0      0.049864
# 1923                           4.0                27270.0      0.045249
# 2084                          81.0              1182669.0      0.044527
# 2245                          21.0               701771.0      0.042726
# 2406                          11.0               200044.0      0.020073
# 2567                          10.0               140213.0      0.033185
# 2728                           8.0               110316.0      0.061643
# 2889                           5.0                31245.0      0.032150
# 3050                          36.0               545152.0      0.049458
# 3211                           3.0                10640.0      0.053124
# 3372                           5.0                40490.0      0.038602
# 3533                           5.0                21585.0      0.057943
# 3694                          90.0              1050855.0      0.041709
# 3855                           9.0               166459.0      0.030096
#
#       Vacant Available %  Vacant Available SF
# 152             0.042572            1691699.0
# 313             0.039103            4275266.0
# 474             0.052618            2532393.0
# 635             0.024909             489583.0
# 796             0.018826             365530.0
# 957             0.051881             514747.0
# 1118            0.042167            4068671.0
# 1279            0.029721             933814.0
# 1440            0.052177            1810976.0
# 1601            0.035548            4911815.0
# 1762            0.047395            1112639.0
# 1923            0.039248             799364.0
# 2084            0.040057            5954751.0
# 2245            0.039443            3121896.0
# 2406            0.019278             346126.0
# 2567            0.031656             962101.0
# 2728            0.058468            1480257.0
# 2889            0.027396             294539.0
# 3050            0.037692            1954465.0
# 3211            0.052894             463651.0
# 3372            0.038602             317610.0
# 3533            0.056881            1421346.0
# 3694            0.037409            6370966.0
# 3855            0.029783             143304.0
#
# [24 rows x 67 columns]

# %%
retail21=retail2[['Period','Geography Name','Inventory SF']]
retail21
# Out:
#        Period             Geography Name  Inventory SF
# 152   2020 Q1         Daytona Beach - FL      39737253
# 313   2020 Q1       Fort Lauderdale - FL     109331087
# 474   2020 Q1            Fort Myers - FL      48127459
# 635   2020 Q1       Ft Walton Beach - FL      19654258
# 796   2020 Q1           Gainesville - FL      19415898
# 957   2020 Q1     Homosassa Springs - FL       9921534
# 1118  2020 Q1          Jacksonville - FL      96488785
# 1279  2020 Q1              Lakeland - FL      31419307
# 1440  2020 Q1             Melbourne - FL      34707799
# 1601  2020 Q1                 Miami - FL     138173131
# 1762  2020 Q1                Naples - FL      23475586
# 1923  2020 Q1                 Ocala - FL      20366721
# 2084  2020 Q1               Orlando - FL     148654414
# 2245  2020 Q1            Palm Beach - FL      79148622
# 2406  2020 Q1           Panama City - FL      17954123
# 2567  2020 Q1             Pensacola - FL      30391534
# 2728  2020 Q1        Port St. Lucie - FL      25316986
# 2889  2020 Q1           Punta Gorda - FL      10750978
# 3050  2020 Q1              Sarasota - FL      51852829
# 3211  2020 Q1  Sebastian-Vero Beach - FL       8765565
# 3372  2020 Q1               Sebring - FL       8227747
# 3533  2020 Q1           Tallahassee - FL      24987649
# 3694  2020 Q1                 Tampa - FL     170305492
# 3855  2020 Q1          The Villages - FL       4811451

# %%
#用2020 q1的数据作为baseline 进行计算
retail21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 152 to 3855
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Period          24 non-null     object
#  1   Geography Name  24 non-null     object
#  2   Inventory SF    24 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 768.0+ bytes

# %%
retail21['Inventory SF'].sum()
# Out:
# 1171986208

# %%
1171986208*0.0003
# Out:
# 351595.8624

# %%
1171986208*0.0005
# Out:
# 585993.104
